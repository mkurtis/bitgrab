# %%
import requests
import json
from pprint import pprint
import os
import re
debug = False

# %%
class BitportBlob(object):
    '''
    The whole schmear.  All your bitport items which are also objects (BitportDirs and BitportFiles)
    '''
    def __init__(self, name):
        self.obj_list = []
        self.auth_tok = ''
        self.me_info = {}
        self.all_bpf_objects = {}
        self.dirs = []
        self.files_to_download = []

# %%
class BitportDir(object):
    '''
    One bitport directory.
    '''
    instance_names = []

    def __init__(self, name):
        self.name = name
        
        self.dictoid = {}
        self.date = ''
        self.name = ''
        self.count = 0
        self.flist = []

# %%
class BitportFile(object):
    '''
    One bitport file.
    '''
    instance_names = []
    fdict = {}
    def __init__(self, name):
        self.name = name
        BitportFile.instance_names.append(self.name)
        
        self.dictoid = {}
        
    #def __del__(self):
    #    print("deling", self)

# %%
def get_secrets_from_file(bitport_dot_file = ''):
    '''
    Keep secret stuff in a .bitport file rather than embedded in the code.
    This utility reads the file and returns a dict.  (or else creates the file.)
    One arg: bitport_dot_file is optional, and defaults to ~/.bitport
    '''
    
    
    # File should contain what dummy_file_content contains (but with real info instead of <..GOES_HERE> stuff)
    dummy_file_content = {
      "client_id":"<CLIENT_ID_GOES_HERE>",
      "client_secret": "<CLIENT_SECRET_GOES_HERE>",
      "code": "<CODE_GOES_HERE>"
    } 
    
    if bitport_dot_file == '':
        home_dir_path = os.path.expanduser('~')
        bitport_dot_file = home_dir_path + '/.bitport'
    
    if os.path.isfile(bitport_dot_file):
        if debug: print ('File {} already exists, reading...'.format(bitport_dot_file))
        

        try:
            with open(bitport_dot_file,  'r') as fh:                                                             
                mystuff = json.load(fh)  

            if debug: print("FOUND FILE CONTENTS: [[[{}]]]".format(mystuff))
        except:
            print('UHHHhhhh, problem with file ', bitport_dot_file, ' game over.')
            
            
        if re.search (r'_GOES_HERE>', mystuff['code']):
            print('Did you forget to edit the file {} ?\n Exiting!'.format(bitport_dot_file))
            exit('Game over')

        return mystuff

            
    else:
        print ('File {} not found.   Creating....'.format(bitport_dot_file))
        print ('You must go edit the file: {}'.format(bitport_dot_file))
        exit('Game over!')

        with open(bitport_dot_file, 'w') as fh:                                                             
            json.dump(dummy_file_content, fh)    
            

        return False

# %%
def get_auth_tok(url='https://api.bitport.io/v2/oauth2/access-token'):
    '''
    This method does a POST to http://bitport.io/get-access to obtain the 'code' (a.k.a. USER_CODE), 
    per the Bitport doc, "thanks to which you can get access_token" [sic]. 

    Beware that the 'code' seems to change occasionally, but the old one still works. So, it may be that
    a human needs to be logged in to a browser and hit the ./get-access site to get a new one occasionally.

    The requests.post below should yield a blob containing 3 items;
    token_type":"Bearer","expires_in":157766399,"access_token":"eyJ0eXAiOiJKV1QiLCJhbGciO...."
    
    We ony care about, (and therefore only return), the 'access_token' item.  Once we have the access_token
    we can make API calls to do useful stuff on the Bitport site.
    
    For more information see the (very terse) Bitport documentation available here: https://bitport.io/api

    '''
    
   
    
    dict1 = get_secrets_from_file()

    payload = {'type': 'application/x-www-form-urlencoded', 
               'client_id':'?', 
               'client_secret': '?', 
               'grant_type': 'code', 
               'code': '?'} 
    
    # We read those things from a file for a reason, they are needed in the payload;
    # We keep them out of the distro / git repo.   They are secrets!
    payload['client_id']     = dict1['client_id']
    payload['client_secret'] = dict1['client_secret']
    payload['code']          = dict1['code']

    if debug: print('Payload is \n'), pprint(payload)
    
    
    r = requests.post(url, data=payload)
    if ( r.status_code != 200 ):
        print("\n\nPOST was a FAILURE!!   status_code = : ", r.status_code, "\n\n")
        return False
    else:
        resp = json.loads(r.text)
        return resp['access_token']

# %%
def jsonify_req_obj(robj):
    import json
    rt = json.loads(robj.text)

    return rt

# %%
def bitport_api_cloud(tok):
    '''
    This returns a top level look at your Bitport cloud content.
    '''
    api_url = 'https://api.bitport.io/v2/cloud'

    header = {'Authorization': tok } 

    rr = requests.get(api_url, headers = header)
    return rr

# %%
def get_a_files_download_url(tok):
    
    ''' 
    Take the so-called 'fileCode', which looks like this: wzskcf8bls
    use that in the https://api.bitport.io/v2/files/<....>/stream.m3u8 url, and 
    get a result that looks like this;
    
    ['#EXTM3U',
     '#EXT-X-VERSION:4',
     '#EXT-X-TARGETDURATION:3556',
     '#EXT-X-MEDIA-SEQUENCE:0',
     '#EXTINF:3556',
     'https://s04.bitport.io/download/uGDWG96J1QRpEFQnntfzsp49vbkK1oba/1',
     '#EXT-X-ENDLIST']
    
    Then parse out and return just the https (url) piece.
    
    '''
    
    api_url = 'https://api.bitport.io/v2/files/wzskcf8bls/stream.m3u8'

    header = {'Authorization': tok } 

    rr = requests.get(api_url, headers = header)
    
    pat = r'(http.+1)\n'
    import re
    found = re.search(pat, rr.text)
    if debug: print('0=[{}]'.format(found.group(0)))
    if debug: print('1=[{}]'.format(found.group(1)))

    if debug: print('finalanswer[[[{}]]]'.format(found.group(1)[3]))

    return found.group(1)

# %%
def get_all_download_urls(bitport_blob_obj):
    
    print (len(bitport_blob_obj.obj_list))
    for jj in bitport_blob_obj.obj_list:

        print('\n\nworking on [{}]'.format(jj.name))
        download_url = get_a_files_download_url(bitport_blob_obj.auth_tok)
        '''
        The download_url should look something like this;
        https://s04.bitport.io/download/uGDWG96J1QRpEFQnntfzsp49vbkK1oba/1
        And undocumented Bitport feature is that there is also a .../2 url
        which provides a smaller (more compressed) MP4 version of the same
        file.   We regex the 1 into a 2 and store that as download_url_sm;
        '''

        download_url_sm = re.sub(r'/1$', '/2', download_url)
        #print("OLD URL = ", download_url)

        #print("NEW URL = ", download_url_sm)

        jj.dictoid['download_url']    = download_url
        jj.dictoid['download_url_sm'] = download_url_sm

        pprint(jj.dictoid)

# %%
def get_me_info_from_api(tok):
    '''
    This returns a top level look at your Bitport cloud content.
    '''
    api_url = 'https://api.bitport.io/v2/me'

    header = {'Authorization': tok } 

    rr = requests.get(api_url, headers = header)
    jj = jsonify_req_obj(rr)
    
    return jj['data']

# %%
def paint_top_folders(bitp_obj):
    
    for ii in range(len(bitp_obj.obj_list)):
        paint_one_row(ii, bitp_obj)

# %%
def ui(bp_obj):
    print('\n################# Info ##################\n')
    print(bp_obj.me_info)
    print('\n################# Top Folders ##################\n')

    paint_top_folders(bp_obj)
    user_input = input('Pick a number:')
    user_input = int(user_input)
    print('You picked {}\n'.format(user_input))
    if debug: print('"ui" calling "paint_one_row" with [{}] and [{}]'.format(user_input, bp_obj.obj_list))
    paint_one_row(user_input, bp_obj)

# %%
def bitport_api_get_folder(tok, dir_code):
    api_url = 'https://api.bitport.io/v2/cloud/' + dir_code
    header = {'Authorization': tok }
    rr = requests.get(api_url, headers = header)
    return rr

# %%
def parse_one_dirs_files_from_api_get_folder_results(bitport_api_get_folder_results):

    dstruct = jsonify_req_obj(bitport_api_get_folder_results)
    min_size = 10000000  # sometimes a 'sample' file is included.  We want to skip it.  Size is in bytes?
    hits = 0
    file_url_prefix = 'https://bitport.io/my-files/file/'
    good_video_file_urls = []
    #pprint(dstruct)


    #print("AAA", dstruct['data'][0])
    print("date=", dstruct['data'][0]['created_at']['date'])
    print("name=", dstruct['data'][0]['name'])
    print("count=", dstruct['data'][0]['files_count'])
    for ff in dstruct['data'][0]['files']:
        temp_dict = {}
        if re.search(r'^sample[.]', ff['name']) and ff['size'] < min_size:
            if debug: print(ff['name'], 'is a small file that starts with "sample.", skipping...')
        elif ff['screenshots'] == []:
            if debug: print(ff['name'], 'has no screenshots, skipping...')
        else:
            hits += 1
            ans = ff
            if debug: print('\tWINNER: ', ff['code'], ff['name'], ff['size'])
            temp_dict['code'] = ff['code']
            temp_dict['parent_folder_code'] = ff['parent_folder_code']
            temp_dict['size'] = ff['size']
            temp_dict['name'] = ff['name']
            temp_dict['date'] = ff['created_at']['date']
            temp_dict['url'] = file_url_prefix + ff['code']

            
            good_video_file_urls.append(temp_dict)
            
    print('parse_one_dirs_files_from_api_get_folder_results() returning with {} items'.format(hits))       
    return good_video_file_urls

# %%
def paint_h():
    
    
    print('{:>3} {:<12} {:<90} {:>5}'.format(
            'Row',
            'Code', 
            'Name',
            'Size(MB)')
         )
    print('{:>3} {:<12} {:<90} {:>5}'.format(
            '=' * 3,
            '=' * 12, 
            '=' * 82,
            '=' * 5)
         )

# %%
def paint_r(row, dictx):
    
    mb = 1024 * 1024
    
    
    if debug: print('I am "paint_r", called with [{}] and [{}]'.format(row, dictx))
    
    print('{:>3} {:<12} {:<90} {:<5.2f}'.format(
            row,
            dictx['code'], 
            dictx['name'],
            dictx['size'] / mb)
         )

# %%
'''def main_guy():
    print("main_guy called...")
    BiBo = BitportBlob('mmm')
    BiBo.auth_tok = get_auth_tok()
    BiBo.me_info = get_me_info_from_api(BiBo.auth_tok)
    BiBo.process_cloud_api_requests_obj(bitport_api_cloud(BiBo.auth_tok))
    # ui(BiBo)
    
    thing = bitport_api_get_folder(BiBo.auth_tok)
    print('mainguy "thing" is type:', type(thing), 'here is contents of thing:')
    pprint(jsonify_req_obj(thing))
    #dstruct = json.loads(thing)
    print('%' * 80)
    #print('idiot')
    #pprint(dstruct)
    return thing
'''
# Out:
# 'def main_guy():\n    print("main_guy called...")\n    BiBo = BitportBlob(\'mmm\')\n    BiBo.auth_tok = get_auth_tok()\n    BiBo.me_info = get_me_info_from_api(BiBo.auth_tok)\n    BiBo.process_cloud_api_requests_obj(bitport_api_cloud(BiBo.auth_tok))\n    # ui(BiBo)\n    \n    thing = bitport_api_get_folder(BiBo.auth_tok)\n    print(\'mainguy "thing" is type:\', type(thing), \'here is contents of thing:\')\n    pprint(jsonify_req_obj(thing))\n    #dstruct = json.loads(thing)\n    print(\'%\' * 80)\n    #print(\'idiot\')\n    #pprint(dstruct)\n    return thing\n'

# %%
def figure_out_dirs( the_cloud_api_requests_object):
    dict_list = []
    xx = jsonify_req_obj(the_cloud_api_requests_object)
    files_dict = xx['data'][0]['folders']
    for file_item in files_dict:
        if file_item['files_count'] > 0:

            temp_obj = BitportDir(file_item['code'])

            temp_obj.dictoid = {'name':         file_item['name'],
                                 'size':        file_item['size'], 
                                 'files_count': file_item['files_count'], 
                                 'code':    file_item['code']  
                                }

            dict_list.append(temp_obj)
    return dict_list

# %%
BiBo = BitportBlob('mmm')
BiBo.auth_tok = get_auth_tok()
BiBo.me_info = get_me_info_from_api(BiBo.auth_tok)
BiBo.dirs = figure_out_dirs(bitport_api_cloud(BiBo.auth_tok))

# %%
def print_top_level_choice(bpobj):
    paint_h()

    for zz in range(len(bpobj.dirs)):
        #print('line {}'.format(zz))
        #print(bpobj.dirs[zz].dictoid)
        paint_r(zz, bpobj.dirs[zz].dictoid)

print_top_level_choice(BiBo)
# Out:
# Row Code         Name                                                                                       Size(MB)
# === ============ ==================================================================================         =====
#   0 8yzfuvl00s   Pinky and the Brain                                                                        17405.20
#   1 leyun3xjvb   Inception.2010.CAM.XviD-TA                                                                 1451.90
#   2 waq2pompk1   Game.of.Thrones.S07E02.720p.HDTV.x264-AVS[rarbg]                                           928.13
#   3 2us5qpavwq   Game.of.Thrones.S07E03.1080p.WEB.h264-TBS[rarbg]                                           1701.70
#   4 40p3set1sc   www.Torrenting.com  - Game.of.Thrones.S07E06.HDTV.x264.AC3-Manning                         1030.30
#   5 nq17okhax4   www.Torrenting.com  - Game.of.Thrones.S07E06.HDTV.x264.AC3-Manning                         1030.30

# %%
for ee in BiBo.dirs:
    pprint(ee.dictoid)
# Out:
# {'code': '8yzfuvl00s',
#  'files_count': 70,
#  'name': 'Pinky and the Brain',
#  'size': 18250676353}
# {'code': 'leyun3xjvb',
#  'files_count': 7,
#  'name': 'Inception.2010.CAM.XviD-TA',
#  'size': 1522427257}
# {'code': 'waq2pompk1',
#  'files_count': 3,
#  'name': 'Game.of.Thrones.S07E02.720p.HDTV.x264-AVS[rarbg]',
#  'size': 973210831}
# {'code': '2us5qpavwq',
#  'files_count': 3,
#  'name': 'Game.of.Thrones.S07E03.1080p.WEB.h264-TBS[rarbg]',
#  'size': 1784365138}
# {'code': '40p3set1sc',
#  'files_count': 2,
#  'name': 'www.Torrenting.com  - Game.of.Thrones.S07E06.HDTV.x264.AC3-Manning',
#  'size': 1080345083}
# {'code': 'nq17okhax4',
#  'files_count': 2,
#  'name': 'www.Torrenting.com  - Game.of.Thrones.S07E06.HDTV.x264.AC3-Manning',
#  'size': 1080345083}

# %%
#thing = bitport_api_get_folder(BiBo.auth_tok, 'leyun3xjvb')
thing = bitport_api_get_folder(BiBo.auth_tok, '8yzfuvl00s')


print(' "thing" is type:', type(thing), 'here is contents of thing:')
pprint(jsonify_req_obj(thing))
#dstruct = json.loads(thing)
print('%' * 80)
#print('idiot')
#pprint(dstruct)
# Out:
#  "thing" is type: <class 'requests.models.Response'> here is contents of thing:
# {'data': [{'code': '8yzfuvl00s',
#            'created_at': {'date': '2017-07-07 16:54:05.000000',
#                           'timezone': 'UTC',
#                           'timezone_type': 3},
#            'files': [{'code': 'cnrdyyzwy3',
#                       'conversion_status': 'converted',
#                       'crc32': 1969185603,
#                       'created_at': {'date': '2017-07-07 16:54:05.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E46 - Dangerous '
#                               'Brains.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/6bea83b1146eb39e_l01.jpg',
#                                       'medium': 'https://static.bitport.io/6bea83b1146eb39e_m01.jpg',
#                                       'small': 'https://static.bitport.io/6bea83b1146eb39e_s01.jpg'},
#                       'size': 279282288,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'e94evbqrkz',
#                       'conversion_status': 'converted',
#                       'crc32': 4242685641,
#                       'created_at': {'date': '2017-07-07 16:54:05.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Animaniacs - S1E98 - Pinky And The Brain - '
#                               'Opportunity Knox.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/5b38f2e55593afde_l01.jpg',
#                                       'medium': 'https://static.bitport.io/5b38f2e55593afde_m01.jpg',
#                                       'small': 'https://static.bitport.io/5b38f2e55593afde_s01.jpg'},
#                       'size': 117655758,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'c4cfacrp5h',
#                       'conversion_status': 'converted',
#                       'crc32': 3962158165,
#                       'created_at': {'date': '2017-07-07 16:54:05.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E5 - Brain Noir.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/c766da65b7ef277e_l01.jpg',
#                                       'medium': 'https://static.bitport.io/c766da65b7ef277e_m01.jpg',
#                                       'small': 'https://static.bitport.io/c766da65b7ef277e_s01.jpg'},
#                       'size': 273802072,
#                       'type': 'video',
#                       'video': True},
#                      {'code': '4wkov28ice',
#                       'conversion_status': 'converted',
#                       'crc32': 2008032954,
#                       'created_at': {'date': '2017-07-07 16:54:05.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Animaniacs - S1E39 - Pinky And The Brain - '
#                               'Where Rodents Dare.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/77c7815c45e03940_l01.jpg',
#                                       'medium': 'https://static.bitport.io/77c7815c45e03940_m01.jpg',
#                                       'small': 'https://static.bitport.io/77c7815c45e03940_s01.jpg'},
#                       'size': 159411944,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'ptj13p1iqm',
#                       'conversion_status': 'converted',
#                       'crc32': 1544664419,
#                       'created_at': {'date': '2017-07-07 16:54:05.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E9 E10 - All You Need '
#                               "Is Narf, Pinky's Plan.avi",
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/ee07698ce558b8b0_l01.jpg',
#                                       'medium': 'https://static.bitport.io/ee07698ce558b8b0_m01.jpg',
#                                       'small': 'https://static.bitport.io/ee07698ce558b8b0_s01.jpg'},
#                       'size': 298278030,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'pgtrzlr1y5',
#                       'conversion_status': 'converted',
#                       'crc32': 3459129470,
#                       'created_at': {'date': '2017-07-07 16:54:05.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E34 E35 - Pinky At The '
#                               'Bat, Schpiel-Borg 2000.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/836d10637cdfe287_l01.jpg',
#                                       'medium': 'https://static.bitport.io/836d10637cdfe287_m01.jpg',
#                                       'small': 'https://static.bitport.io/836d10637cdfe287_s01.jpg'},
#                       'size': 279416368,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'lsotejeosx',
#                       'conversion_status': 'converted',
#                       'crc32': 1315651076,
#                       'created_at': {'date': '2017-07-07 16:54:05.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E36 - Broadway '
#                               'Malady.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/0cb01eb387042927_l01.jpg',
#                                       'medium': 'https://static.bitport.io/0cb01eb387042927_m01.jpg',
#                                       'small': 'https://static.bitport.io/0cb01eb387042927_s01.jpg'},
#                       'size': 284385698,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'n17umcud4f',
#                       'conversion_status': 'converted',
#                       'crc32': 2076658188,
#                       'created_at': {'date': '2017-07-07 16:54:05.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S4E1 - Brainwashed(1) '
#                               'Brain, Brain, Go Away.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/65aa05891a88749c_l01.jpg',
#                                       'medium': 'https://static.bitport.io/65aa05891a88749c_m01.jpg',
#                                       'small': 'https://static.bitport.io/65aa05891a88749c_s01.jpg'},
#                       'size': 279851036,
#                       'type': 'video',
#                       'video': True},
#                      {'code': '2qzt0c6a4q',
#                       'conversion_status': 'converted',
#                       'crc32': 635619592,
#                       'created_at': {'date': '2017-07-07 16:54:05.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E25 - A Pinky And The '
#                               'Brain Halloween.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/fb9ba7bb085fca99_l01.jpg',
#                                       'medium': 'https://static.bitport.io/fb9ba7bb085fca99_m01.jpg',
#                                       'small': 'https://static.bitport.io/fb9ba7bb085fca99_s01.jpg'},
#                       'size': 292895778,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'yv6028n48z',
#                       'conversion_status': 'converted',
#                       'crc32': 2182219337,
#                       'created_at': {'date': '2017-07-07 16:54:05.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': "Pinky And The Brain - S3E29 - But, That's Not "
#                               'All Folks!.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/c6ac0b79e6186019_l01.jpg',
#                                       'medium': 'https://static.bitport.io/c6ac0b79e6186019_m01.jpg',
#                                       'small': 'https://static.bitport.io/c6ac0b79e6186019_s01.jpg'},
#                       'size': 274339130,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'z94etenqr1',
#                       'conversion_status': 'converted',
#                       'crc32': 667375832,
#                       'created_at': {'date': '2017-07-07 16:54:05.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E1 E2 - Leave It To '
#                               'Beavers, Cinebrania.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/57240430079cc582_l01.jpg',
#                                       'medium': 'https://static.bitport.io/57240430079cc582_m01.jpg',
#                                       'small': 'https://static.bitport.io/57240430079cc582_s01.jpg'},
#                       'size': 278044000,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'pah6g0vh74',
#                       'conversion_status': 'converted',
#                       'crc32': 2997232411,
#                       'created_at': {'date': '2017-07-07 16:54:05.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E37 E38 - The '
#                               'Megalomaniacal Adventures Of Brainie The Poo - '
#                               'The Melancholy Brain.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/d02b7b82d7b981f0_l01.jpg',
#                                       'medium': 'https://static.bitport.io/d02b7b82d7b981f0_m01.jpg',
#                                       'small': 'https://static.bitport.io/d02b7b82d7b981f0_s01.jpg'},
#                       'size': 279656056,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'j3hyym3n07',
#                       'conversion_status': 'converted',
#                       'crc32': 2398853953,
#                       'created_at': {'date': '2017-07-07 16:54:05.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S4E6 - The Pinky And The '
#                               'Brain Reunion Special.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/323ed50a74e76867_l01.jpg',
#                                       'medium': 'https://static.bitport.io/323ed50a74e76867_m01.jpg',
#                                       'small': 'https://static.bitport.io/323ed50a74e76867_s01.jpg'},
#                       'size': 282108316,
#                       'type': 'video',
#                       'video': True},
#                      {'code': '26gxt7zbru',
#                       'conversion_status': 'converted',
#                       'crc32': 1683042001,
#                       'created_at': {'date': '2017-07-07 16:54:05.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S1E15 - Fly.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/cb9f8b97a30d95cb_l01.jpg',
#                                       'medium': 'https://static.bitport.io/cb9f8b97a30d95cb_m01.jpg',
#                                       'small': 'https://static.bitport.io/cb9f8b97a30d95cb_s01.jpg'},
#                       'size': 275416094,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'nl7jzr04us',
#                       'conversion_status': 'converted',
#                       'crc32': 97443055,
#                       'created_at': {'date': '2017-07-07 16:54:06.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S1E1 - Das Mouse.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/8bbc443268fc6fd9_l01.jpg',
#                                       'medium': 'https://static.bitport.io/8bbc443268fc6fd9_m01.jpg',
#                                       'small': 'https://static.bitport.io/8bbc443268fc6fd9_s01.jpg'},
#                       'size': 275443360,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'w3dfhbiryo',
#                       'conversion_status': 'converted',
#                       'crc32': 628557323,
#                       'created_at': {'date': '2017-07-07 16:54:06.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Animaniacs - S1E2 - Pinky And The Brain - Win '
#                               'Big.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/89bd5e563afab17d_l01.jpg',
#                                       'medium': 'https://static.bitport.io/89bd5e563afab17d_m01.jpg',
#                                       'small': 'https://static.bitport.io/89bd5e563afab17d_s01.jpg'},
#                       'size': 82650024,
#                       'type': 'video',
#                       'video': True},
#                      {'code': '5e5r1xb256',
#                       'conversion_status': 'converted',
#                       'crc32': 3896471265,
#                       'created_at': {'date': '2017-07-07 16:54:06.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E19 E20 - Pinky And The '
#                               'Brainmaker, Calvin Brain.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/2d2d2eca94393156_l01.jpg',
#                                       'medium': 'https://static.bitport.io/2d2d2eca94393156_m01.jpg',
#                                       'small': 'https://static.bitport.io/2d2d2eca94393156_s01.jpg'},
#                       'size': 275203520,
#                       'type': 'video',
#                       'video': True},
#                      {'code': '995x0fuq2m',
#                       'conversion_status': 'converted',
#                       'crc32': 4238772274,
#                       'created_at': {'date': '2017-07-07 16:54:06.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E42 - The Family That '
#                               'Poits Together, Narfs Together.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/b2e4f6a035a0e42f_l01.jpg',
#                                       'medium': 'https://static.bitport.io/b2e4f6a035a0e42f_m01.jpg',
#                                       'small': 'https://static.bitport.io/b2e4f6a035a0e42f_s01.jpg'},
#                       'size': 280633640,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'nx8w674ihk',
#                       'conversion_status': 'converted',
#                       'crc32': 486272787,
#                       'created_at': {'date': '2017-07-07 16:54:06.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S4E2 - Brainwashed(2) I '
#                               'Am Not a Hat.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/56230bbe090e746c_l01.jpg',
#                                       'medium': 'https://static.bitport.io/56230bbe090e746c_m01.jpg',
#                                       'small': 'https://static.bitport.io/56230bbe090e746c_s01.jpg'},
#                       'size': 284050340,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'z3qcie9zk2',
#                       'conversion_status': 'converted',
#                       'crc32': 2262774406,
#                       'created_at': {'date': '2017-07-07 16:54:06.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E49 E50 E51 - The Pinky '
#                               'P.O.V., The Really Great Dictator, Brain '
#                               'Food.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/f19628c528c93c10_l01.jpg',
#                                       'medium': 'https://static.bitport.io/f19628c528c93c10_m01.jpg',
#                                       'small': 'https://static.bitport.io/f19628c528c93c10_s01.jpg'},
#                       'size': 277244974,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'youaldqqbi',
#                       'conversion_status': 'converted',
#                       'crc32': 4110123232,
#                       'created_at': {'date': '2017-07-07 16:54:06.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E3 E4 - Pinky And The '
#                               'Brain ...And Larry, Where the Deer and the '
#                               'Mouselopes Play.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/363223f97a57b064_l01.jpg',
#                                       'medium': 'https://static.bitport.io/363223f97a57b064_m01.jpg',
#                                       'small': 'https://static.bitport.io/363223f97a57b064_s01.jpg'},
#                       'size': 276736218,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'uo6wj2szbx',
#                       'conversion_status': 'converted',
#                       'crc32': 2573958561,
#                       'created_at': {'date': '2017-07-07 16:54:06.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S1E10 - TV Or Not TV.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/015145d0206ea92d_l01.jpg',
#                                       'medium': 'https://static.bitport.io/015145d0206ea92d_m01.jpg',
#                                       'small': 'https://static.bitport.io/015145d0206ea92d_s01.jpg'},
#                       'size': 273711680,
#                       'type': 'video',
#                       'video': True},
#                      {'code': '2b1nkc0vj4',
#                       'conversion_status': 'converted',
#                       'crc32': 3731668404,
#                       'created_at': {'date': '2017-07-07 16:54:06.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E27 E28 - Leggo My Ego, '
#                               'Big In Japan.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/703e8684098e7e58_l01.jpg',
#                                       'medium': 'https://static.bitport.io/703e8684098e7e58_m01.jpg',
#                                       'small': 'https://static.bitport.io/703e8684098e7e58_s01.jpg'},
#                       'size': 287597366,
#                       'type': 'video',
#                       'video': True},
#                      {'code': '9kb8lrse6u',
#                       'conversion_status': 'converted',
#                       'crc32': 2804278943,
#                       'created_at': {'date': '2017-07-07 16:54:06.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': "Pinky And The Brain - S3E45 - You'll Never Eat "
#                               'Food Pellets In This Town, Again!.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/23fcc98f385be569_l01.jpg',
#                                       'medium': 'https://static.bitport.io/23fcc98f385be569_m01.jpg',
#                                       'small': 'https://static.bitport.io/23fcc98f385be569_s01.jpg'},
#                       'size': 280838984,
#                       'type': 'video',
#                       'video': True},
#                      {'code': '75odf161c5',
#                       'conversion_status': 'converted',
#                       'crc32': 3672240472,
#                       'created_at': {'date': '2017-07-07 16:54:06.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Animaniacs - S1E15 - Pinky And The Brain - '
#                               'Battle for the Planet.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/14841e984ed3ccc9_l01.jpg',
#                                       'medium': 'https://static.bitport.io/14841e984ed3ccc9_m01.jpg',
#                                       'small': 'https://static.bitport.io/14841e984ed3ccc9_s01.jpg'},
#                       'size': 77796388,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'f3k6by5hxo',
#                       'conversion_status': 'converted',
#                       'crc32': 1389661794,
#                       'created_at': {'date': '2017-07-07 16:54:06.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E21 E22 - Pinky Suavo, '
#                               'T.H.E.Y.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/540ba51b48c151cc_l01.jpg',
#                                       'medium': 'https://static.bitport.io/540ba51b48c151cc_m01.jpg',
#                                       'small': 'https://static.bitport.io/540ba51b48c151cc_s01.jpg'},
#                       'size': 264533082,
#                       'type': 'video',
#                       'video': True},
#                      {'code': '41fuwbbe7p',
#                       'conversion_status': 'converted',
#                       'crc32': 2375477068,
#                       'created_at': {'date': '2017-07-07 16:54:06.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S1E9 - Brainania.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/e82ef04c632429e2_l01.jpg',
#                                       'medium': 'https://static.bitport.io/e82ef04c632429e2_m01.jpg',
#                                       'small': 'https://static.bitport.io/e82ef04c632429e2_s01.jpg'},
#                       'size': 278900550,
#                       'type': 'video',
#                       'video': True},
#                      {'code': '299n7x1oi0',
#                       'conversion_status': 'converted',
#                       'crc32': 2360770051,
#                       'created_at': {'date': '2017-07-07 16:54:06.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E12 - Brain Storm.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/958ec9d676e18aa2_l01.jpg',
#                                       'medium': 'https://static.bitport.io/958ec9d676e18aa2_m01.jpg',
#                                       'small': 'https://static.bitport.io/958ec9d676e18aa2_s01.jpg'},
#                       'size': 276930630,
#                       'type': 'video',
#                       'video': True},
#                      {'code': '7jdhxdzbsl',
#                       'conversion_status': 'converted',
#                       'crc32': 2568344020,
#                       'created_at': {'date': '2017-07-07 16:54:06.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S1E3 E4 E5 - Tokyo Grows, '
#                               'That Smarts, Brainstem.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/b9da1ae820b7fd46_l01.jpg',
#                                       'medium': 'https://static.bitport.io/b9da1ae820b7fd46_m01.jpg',
#                                       'small': 'https://static.bitport.io/b9da1ae820b7fd46_s01.jpg'},
#                       'size': 290025116,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'swtu9k8wio',
#                       'conversion_status': 'converted',
#                       'crc32': 2719593759,
#                       'created_at': {'date': '2017-07-07 16:54:06.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S2E4 - Plan Brain From '
#                               'Outer Space.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/33d8a9ab3b86f103_l01.jpg',
#                                       'medium': 'https://static.bitport.io/33d8a9ab3b86f103_m01.jpg',
#                                       'small': 'https://static.bitport.io/33d8a9ab3b86f103_s01.jpg'},
#                       'size': 270318430,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'yol9rt1tug',
#                       'conversion_status': 'converted',
#                       'crc32': 4259951085,
#                       'created_at': {'date': '2017-07-07 16:54:06.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': "Pinky And The Brain - S2E1 - It's Only a Paper "
#                               'World.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/80c3f37a3ebddfba_l01.jpg',
#                                       'medium': 'https://static.bitport.io/80c3f37a3ebddfba_m01.jpg',
#                                       'small': 'https://static.bitport.io/80c3f37a3ebddfba_s01.jpg'},
#                       'size': 266553270,
#                       'type': 'video',
#                       'video': True},
#                      {'code': '5fs0k9ralt',
#                       'conversion_status': 'converted',
#                       'crc32': 1072101350,
#                       'created_at': {'date': '2017-07-07 16:54:06.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S1E6 E7 E8 - Pinky And '
#                               'The Fog, Where No Mouse Has Gone Before, Cheese '
#                               'Roll Call.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/1435b9ede4107a67_l01.jpg',
#                                       'medium': 'https://static.bitport.io/1435b9ede4107a67_m01.jpg',
#                                       'small': 'https://static.bitport.io/1435b9ede4107a67_s01.jpg'},
#                       'size': 281996910,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'tc4nm7j9p0',
#                       'conversion_status': 'converted',
#                       'crc32': 652052169,
#                       'created_at': {'date': '2017-07-07 16:54:06.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E18 - Brain Acres.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/8311a353e7a89a40_l01.jpg',
#                                       'medium': 'https://static.bitport.io/8311a353e7a89a40_m01.jpg',
#                                       'small': 'https://static.bitport.io/8311a353e7a89a40_s01.jpg'},
#                       'size': 278359348,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'kx5kg0xm4r',
#                       'conversion_status': 'converted',
#                       'crc32': 2581412198,
#                       'created_at': {'date': '2017-07-07 16:54:06.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E47 E48 - Whatever '
#                               'Happened To Baby Brain, Just Say Narf.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/f43a3cd8ef6b382a_l01.jpg',
#                                       'medium': 'https://static.bitport.io/f43a3cd8ef6b382a_m01.jpg',
#                                       'small': 'https://static.bitport.io/f43a3cd8ef6b382a_s01.jpg'},
#                       'size': 278182484,
#                       'type': 'video',
#                       'video': True},
#                      {'code': '10hba474xp',
#                       'conversion_status': 'converted',
#                       'crc32': 3473760531,
#                       'created_at': {'date': '2017-07-07 16:54:06.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S1E13 - Snowball.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/000d50cb00de090e_l01.jpg',
#                                       'medium': 'https://static.bitport.io/000d50cb00de090e_m01.jpg',
#                                       'small': 'https://static.bitport.io/000d50cb00de090e_s01.jpg'},
#                       'size': 282784736,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'f1n7m7sq37',
#                       'conversion_status': 'converted',
#                       'crc32': 4068205318,
#                       'created_at': {'date': '2017-07-07 16:54:06.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E26 - Brainy Jack.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/9c9a0ec557aa0be7_l01.jpg',
#                                       'medium': 'https://static.bitport.io/9c9a0ec557aa0be7_m01.jpg',
#                                       'small': 'https://static.bitport.io/9c9a0ec557aa0be7_s01.jpg'},
#                       'size': 278413578,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'xu6wrtry82',
#                       'conversion_status': 'converted',
#                       'crc32': 3845374885,
#                       'created_at': {'date': '2017-07-07 16:54:07.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': "Pinky And The Brain - S3E43 E44 - Pinky's Turn, "
#                               'Your Friend Global Domination.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/58ebca280d05458a_l01.jpg',
#                                       'medium': 'https://static.bitport.io/58ebca280d05458a_m01.jpg',
#                                       'small': 'https://static.bitport.io/58ebca280d05458a_s01.jpg'},
#                       'size': 277586818,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'aelibu3ot4',
#                       'conversion_status': 'converted',
#                       'crc32': 1909837418,
#                       'created_at': {'date': '2017-07-07 16:54:07.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S2E9 - Welcome To The '
#                               'Jungle.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/4287aaebfc48def3_l01.jpg',
#                                       'medium': 'https://static.bitport.io/4287aaebfc48def3_m01.jpg',
#                                       'small': 'https://static.bitport.io/4287aaebfc48def3_s01.jpg'},
#                       'size': 292788076,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'akl5ckjezj',
#                       'conversion_status': 'converted',
#                       'crc32': 2291565121,
#                       'created_at': {'date': '2017-07-07 16:54:07.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S4E9 - Star Warners.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/8f039ea33489b2ba_l01.jpg',
#                                       'medium': 'https://static.bitport.io/8f039ea33489b2ba_m01.jpg',
#                                       'small': 'https://static.bitport.io/8f039ea33489b2ba_s01.jpg'},
#                       'size': 225093446,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'ak4j5quaha',
#                       'conversion_status': 'converted',
#                       'crc32': 1077319967,
#                       'created_at': {'date': '2017-07-07 16:54:07.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E39 - Inherit The '
#                               'Wheeze.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/d650d451296c25d7_l01.jpg',
#                                       'medium': 'https://static.bitport.io/d650d451296c25d7_m01.jpg',
#                                       'small': 'https://static.bitport.io/d650d451296c25d7_s01.jpg'},
#                       'size': 275679548,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'slz77fn7ur',
#                       'conversion_status': 'converted',
#                       'crc32': 2165566106,
#                       'created_at': {'date': '2017-07-07 16:54:07.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E11 - This Old '
#                               'Mouse.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/e4eeee7c81d5d99b_l01.jpg',
#                                       'medium': 'https://static.bitport.io/e4eeee7c81d5d99b_m01.jpg',
#                                       'small': 'https://static.bitport.io/e4eeee7c81d5d99b_s01.jpg'},
#                       'size': 268984210,
#                       'type': 'video',
#                       'video': True},
#                      {'code': '5h6ruhnqqp',
#                       'conversion_status': 'converted',
#                       'crc32': 3566588908,
#                       'created_at': {'date': '2017-07-07 16:54:07.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': "Pinky And The Brain - S3E24 - Brain's Way.avi",
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/245bc8ba6b5c026d_l01.jpg',
#                                       'medium': 'https://static.bitport.io/245bc8ba6b5c026d_m01.jpg',
#                                       'small': 'https://static.bitport.io/245bc8ba6b5c026d_s01.jpg'},
#                       'size': 279438084,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'cm4hnhqtgn',
#                       'conversion_status': 'converted',
#                       'crc32': 1122591174,
#                       'created_at': {'date': '2017-07-07 16:54:07.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S2E5 E6 - Robin Brain, '
#                               'The Mummy.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/7a0696558b2bd8f2_l01.jpg',
#                                       'medium': 'https://static.bitport.io/7a0696558b2bd8f2_m01.jpg',
#                                       'small': 'https://static.bitport.io/7a0696558b2bd8f2_s01.jpg'},
#                       'size': 283324944,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'c4xhlmjcsu',
#                       'conversion_status': 'converted',
#                       'crc32': 2651129875,
#                       'created_at': {'date': '2017-07-07 16:54:07.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S2E10 E11 - A Little Off '
#                               'the Top, Megalomaniacs Anonymous.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/099960552c6bc2ea_l01.jpg',
#                                       'medium': 'https://static.bitport.io/099960552c6bc2ea_m01.jpg',
#                                       'small': 'https://static.bitport.io/099960552c6bc2ea_s01.jpg'},
#                       'size': 258316526,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'f6oam7i6kh',
#                       'conversion_status': 'converted',
#                       'crc32': 3261523164,
#                       'created_at': {'date': '2017-07-07 16:54:07.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S2E16 - Hoop Schemes.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/dbf675cb2d2078fe_l01.jpg',
#                                       'medium': 'https://static.bitport.io/dbf675cb2d2078fe_m01.jpg',
#                                       'small': 'https://static.bitport.io/dbf675cb2d2078fe_s01.jpg'},
#                       'size': 277490852,
#                       'type': 'video',
#                       'video': True},
#                      {'code': '16rdodtbgx',
#                       'conversion_status': 'converted',
#                       'crc32': 2333470893,
#                       'created_at': {'date': '2017-07-07 16:54:07.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E23 - The Real Life.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/325feb9a4b43bc7c_l01.jpg',
#                                       'medium': 'https://static.bitport.io/325feb9a4b43bc7c_m01.jpg',
#                                       'small': 'https://static.bitport.io/325feb9a4b43bc7c_s01.jpg'},
#                       'size': 291195178,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'e4lawhx85t',
#                       'conversion_status': 'converted',
#                       'crc32': 1101139551,
#                       'created_at': {'date': '2017-07-07 16:54:07.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S2E15 - Brinky.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/b5cdab155f3bbd29_l01.jpg',
#                                       'medium': 'https://static.bitport.io/b5cdab155f3bbd29_m01.jpg',
#                                       'small': 'https://static.bitport.io/b5cdab155f3bbd29_s01.jpg'},
#                       'size': 277798916,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'qvyvuolas0',
#                       'conversion_status': 'converted',
#                       'crc32': 2491400529,
#                       'created_at': {'date': '2017-07-07 16:54:08.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S4E4 E5 - To Russia With '
#                               'Lab Mice, Hickory Dickory Bonk.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/0c79625387d6cd59_l01.jpg',
#                                       'medium': 'https://static.bitport.io/0c79625387d6cd59_m01.jpg',
#                                       'small': 'https://static.bitport.io/0c79625387d6cd59_s01.jpg'},
#                       'size': 277221362,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'vml5hbh39h',
#                       'conversion_status': 'converted',
#                       'crc32': 778143748,
#                       'created_at': {'date': '2017-07-07 16:54:08.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S4E3 - Brainwashed(3) '
#                               'Wash Harder.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/302fcd4200b52fb3_l01.jpg',
#                                       'medium': 'https://static.bitport.io/302fcd4200b52fb3_m01.jpg',
#                                       'small': 'https://static.bitport.io/302fcd4200b52fb3_s01.jpg'},
# ...
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S2E7 - The Pink '
#                               'Candidate.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/2557cf9d4002ae8b_l01.jpg',
#                                       'medium': 'https://static.bitport.io/2557cf9d4002ae8b_m01.jpg',
#                                       'small': 'https://static.bitport.io/2557cf9d4002ae8b_s01.jpg'},
#                       'size': 280754452,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'i8wtfd02un',
#                       'conversion_status': 'converted',
#                       'crc32': 2372350209,
#                       'created_at': {'date': '2017-07-07 16:54:08.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S1E16 E17 - Ambulatory '
#                               'Abe, Mouse of la Mancha.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/13b7af3aa6bbc98f_l01.jpg',
#                                       'medium': 'https://static.bitport.io/13b7af3aa6bbc98f_m01.jpg',
#                                       'small': 'https://static.bitport.io/13b7af3aa6bbc98f_s01.jpg'},
#                       'size': 266425786,
#                       'type': 'video',
#                       'video': True},
#                      {'code': '55kj3jujrh',
#                       'conversion_status': 'converted',
#                       'crc32': 929167106,
#                       'created_at': {'date': '2017-07-07 16:54:08.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Animaniacs - S1E18 - Pinky And The Brain - '
#                               "Pavlov's Mice + Animaniac's intro.avi",
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/e846e5ae80151aa6_l01.jpg',
#                                       'medium': 'https://static.bitport.io/e846e5ae80151aa6_m01.jpg',
#                                       'small': 'https://static.bitport.io/e846e5ae80151aa6_s01.jpg'},
#                       'size': 88270824,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'dntbgsl97q',
#                       'conversion_status': 'converted',
#                       'crc32': 4227146162,
#                       'created_at': {'date': '2017-07-07 16:54:08.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E30 E31 - Operation Sea '
#                               'Lion, You Said A Mouseful.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/b9e2d20bb6fba422_l01.jpg',
#                                       'medium': 'https://static.bitport.io/b9e2d20bb6fba422_m01.jpg',
#                                       'small': 'https://static.bitport.io/b9e2d20bb6fba422_s01.jpg'},
#                       'size': 282205922,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'aa9cqap33a',
#                       'conversion_status': 'converted',
#                       'crc32': 2713991005,
#                       'created_at': {'date': '2017-07-07 16:54:08.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': "Pinky And The Brain - S3E16 E17 - Mice Don't "
#                               'Dance, Brain Drained.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/7462731f74ebd3a9_l01.jpg',
#                                       'medium': 'https://static.bitport.io/7462731f74ebd3a9_m01.jpg',
#                                       'small': 'https://static.bitport.io/7462731f74ebd3a9_s01.jpg'},
#                       'size': 280398468,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'hqt54qi9wu',
#                       'conversion_status': 'converted',
#                       'crc32': 78913393,
#                       'created_at': {'date': '2017-07-07 16:54:08.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': "Pinky And The Brain - S2E8 - Brain's Song.avi",
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/6a9d6ff991ffcefd_l01.jpg',
#                                       'medium': 'https://static.bitport.io/6a9d6ff991ffcefd_m01.jpg',
#                                       'small': 'https://static.bitport.io/6a9d6ff991ffcefd_s01.jpg'},
#                       'size': 272641330,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'znt9mci3z4',
#                       'conversion_status': 'converted',
#                       'crc32': 3599047182,
#                       'created_at': {'date': '2017-07-07 16:54:08.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S2E12 E13 - Two Mice and '
#                               'a Baby, The Maze.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/c961ce4cc85434b1_l01.jpg',
#                                       'medium': 'https://static.bitport.io/c961ce4cc85434b1_m01.jpg',
#                                       'small': 'https://static.bitport.io/c961ce4cc85434b1_s01.jpg'},
#                       'size': 281928708,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'az18vve4gs',
#                       'conversion_status': 'converted',
#                       'crc32': 1306230018,
#                       'created_at': {'date': '2017-07-07 16:54:08.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': "Pinky And The Brain - S3E40 E41 - Brain's Night "
#                               'Off - Beach Blanket Brain.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/9afa0347b908241a_l01.jpg',
#                                       'medium': 'https://static.bitport.io/9afa0347b908241a_m01.jpg',
#                                       'small': 'https://static.bitport.io/9afa0347b908241a_s01.jpg'},
#                       'size': 279590664,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'az05stfsqy',
#                       'conversion_status': 'converted',
#                       'crc32': 286939079,
#                       'created_at': {'date': '2017-07-07 16:54:08.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S1E18 E19 - The Third '
#                               'Mouse, The Visit.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/9fbc28478cb099ba_l01.jpg',
#                                       'medium': 'https://static.bitport.io/9fbc28478cb099ba_m01.jpg',
#                                       'small': 'https://static.bitport.io/9fbc28478cb099ba_s01.jpg'},
#                       'size': 293787928,
#                       'type': 'video',
#                       'video': True},
#                      {'code': '9ej8tav3jk',
#                       'conversion_status': 'converted',
#                       'crc32': 1140323718,
#                       'created_at': {'date': '2017-07-07 16:54:08.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E8 - My Feldmans, My '
#                               'Friends.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/0732ee636b92aac9_l01.jpg',
#                                       'medium': 'https://static.bitport.io/0732ee636b92aac9_m01.jpg',
#                                       'small': 'https://static.bitport.io/0732ee636b92aac9_s01.jpg'},
#                       'size': 251991016,
#                       'type': 'video',
#                       'video': True},
#                      {'code': '1wk1mff72e',
#                       'conversion_status': 'converted',
#                       'crc32': 1880503023,
#                       'created_at': {'date': '2017-07-07 16:54:08.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E15 - The Pinky '
#                               'Protocol.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/64a84216afbaa612_l01.jpg',
#                                       'medium': 'https://static.bitport.io/64a84216afbaa612_m01.jpg',
#                                       'small': 'https://static.bitport.io/64a84216afbaa612_s01.jpg'},
#                       'size': 263624082,
#                       'type': 'video',
#                       'video': True},
#                      {'code': '06oih1wxtj',
#                       'conversion_status': 'converted',
#                       'crc32': 723742568,
#                       'created_at': {'date': '2017-07-07 16:54:08.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E32 E33 - The Tailor '
#                               'And The Mice, Bah, Wilderness.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/2a3b97d2b0720ecf_l01.jpg',
#                                       'medium': 'https://static.bitport.io/2a3b97d2b0720ecf_m01.jpg',
#                                       'small': 'https://static.bitport.io/2a3b97d2b0720ecf_s01.jpg'},
#                       'size': 277253784,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'jw66emv9bc',
#                       'conversion_status': 'converted',
#                       'crc32': 410569641,
#                       'created_at': {'date': '2017-07-07 16:54:08.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S4E7 E8 - A Legendary '
#                               'Tail, Project B.R.A.I.N..avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/bfc9bebfbe034c48_l01.jpg',
#                                       'medium': 'https://static.bitport.io/bfc9bebfbe034c48_m01.jpg',
#                                       'small': 'https://static.bitport.io/bfc9bebfbe034c48_s01.jpg'},
#                       'size': 278511034,
#                       'type': 'video',
#                       'video': True},
#                      {'code': '8s33di8lnv',
#                       'conversion_status': 'converted',
#                       'crc32': 2317738536,
#                       'created_at': {'date': '2017-07-07 16:54:08.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S3E13 E14 - A Meticulous '
#                               "Analysis Of History, Funny, You Don't Look "
#                               'Rhennish.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/5592aa947f7d8671_l01.jpg',
#                                       'medium': 'https://static.bitport.io/5592aa947f7d8671_m01.jpg',
#                                       'small': 'https://static.bitport.io/5592aa947f7d8671_s01.jpg'},
#                       'size': 277822796,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'z6knmonyd6',
#                       'conversion_status': 'converted',
#                       'crc32': 2069227846,
#                       'created_at': {'date': '2017-07-07 16:54:08.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': 'Pinky And The Brain - S2E14 - Brain Of The '
#                               'Future.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/b5a6e67cfb730cec_l01.jpg',
#                                       'medium': 'https://static.bitport.io/b5a6e67cfb730cec_m01.jpg',
#                                       'small': 'https://static.bitport.io/b5a6e67cfb730cec_s01.jpg'},
#                       'size': 271928010,
#                       'type': 'video',
#                       'video': True},
#                      {'code': 'dj0p2tip93',
#                       'conversion_status': 'converted',
#                       'crc32': 3667005033,
#                       'created_at': {'date': '2017-07-07 16:54:08.000000',
#                                      'timezone': 'UTC',
#                                      'timezone_type': 3},
#                       'extension': 'avi',
#                       'name': "Pinky And The Brain - S2E2 E3 - Collect 'Em "
#                               'All, Pinkasso.avi',
#                       'parent_folder_code': '8yzfuvl00s',
#                       'screenshots': {'big': 'https://static.bitport.io/f440eb44dd7e8e86_l01.jpg',
#                                       'medium': 'https://static.bitport.io/f440eb44dd7e8e86_m01.jpg',
#                                       'small': 'https://static.bitport.io/f440eb44dd7e8e86_s01.jpg'},
#                       'size': 267731212,
#                       'type': 'video',
#                       'video': True}],
#            'files_count': 70,
#            'folders': [],
#            'name': 'Pinky and the Brain',
#            'parent_folder': {'code': None,
#                              'created_at': None,
#                              'files_count': None,
#                              'name': 'My files',
#                              'size': 27131316214},
#            'size': 18250676353}],
#  'errors': None,
#  'status': 'success'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# %%
a_bitport_dir_ob = BitportDir('shiiizz')
a_bitport_dir_ob.flist = parse_one_dirs_files_from_api_get_folder_results(thing)
#pprint(a_bitport_dir_ob.flist)

paint_h()
for item_num in range(len(a_bitport_dir_ob.flist)):
    paint_r(item_num, a_bitport_dir_ob.flist[item_num])
# Out:
# date= 2017-07-07 16:54:05.000000
# name= Pinky and the Brain
# count= 70
# parse_one_dirs_files_from_api_get_folder_results() returning with 69 items
# Row Code         Name                                                                                       Size(MB)
# === ============ ==================================================================================         =====
#   0 cnrdyyzwy3   Pinky And The Brain - S3E46 - Dangerous Brains.avi                                         266.34
#   1 e94evbqrkz   Animaniacs - S1E98 - Pinky And The Brain - Opportunity Knox.avi                            112.21
#   2 c4cfacrp5h   Pinky And The Brain - S3E5 - Brain Noir.avi                                                261.12
#   3 4wkov28ice   Animaniacs - S1E39 - Pinky And The Brain - Where Rodents Dare.avi                          152.03
#   4 ptj13p1iqm   Pinky And The Brain - S3E9 E10 - All You Need Is Narf, Pinky's Plan.avi                    284.46
#   5 pgtrzlr1y5   Pinky And The Brain - S3E34 E35 - Pinky At The Bat, Schpiel-Borg 2000.avi                  266.47
#   6 lsotejeosx   Pinky And The Brain - S3E36 - Broadway Malady.avi                                          271.21
#   7 n17umcud4f   Pinky And The Brain - S4E1 - Brainwashed(1) Brain, Brain, Go Away.avi                      266.89
#   8 2qzt0c6a4q   Pinky And The Brain - S3E25 - A Pinky And The Brain Halloween.avi                          279.33
#   9 yv6028n48z   Pinky And The Brain - S3E29 - But, That's Not All Folks!.avi                               261.63
#  10 z94etenqr1   Pinky And The Brain - S3E1 E2 - Leave It To Beavers, Cinebrania.avi                        265.16
#  11 pah6g0vh74   Pinky And The Brain - S3E37 E38 - The Megalomaniacal Adventures Of Brainie The Poo - The Melancholy Brain.avi 266.70
#  12 j3hyym3n07   Pinky And The Brain - S4E6 - The Pinky And The Brain Reunion Special.avi                   269.04
#  13 26gxt7zbru   Pinky And The Brain - S1E15 - Fly.avi                                                      262.66
#  14 nl7jzr04us   Pinky And The Brain - S1E1 - Das Mouse.avi                                                 262.68
#  15 w3dfhbiryo   Animaniacs - S1E2 - Pinky And The Brain - Win Big.avi                                      78.82
#  16 5e5r1xb256   Pinky And The Brain - S3E19 E20 - Pinky And The Brainmaker, Calvin Brain.avi               262.45
#  17 995x0fuq2m   Pinky And The Brain - S3E42 - The Family That Poits Together, Narfs Together.avi           267.63
#  18 nx8w674ihk   Pinky And The Brain - S4E2 - Brainwashed(2) I Am Not a Hat.avi                             270.89
#  19 z3qcie9zk2   Pinky And The Brain - S3E49 E50 E51 - The Pinky P.O.V., The Really Great Dictator, Brain Food.avi 264.40
#  20 youaldqqbi   Pinky And The Brain - S3E3 E4 - Pinky And The Brain ...And Larry, Where the Deer and the Mouselopes Play.avi 263.92
#  21 uo6wj2szbx   Pinky And The Brain - S1E10 - TV Or Not TV.avi                                             261.03
#  22 2b1nkc0vj4   Pinky And The Brain - S3E27 E28 - Leggo My Ego, Big In Japan.avi                           274.27
#  23 9kb8lrse6u   Pinky And The Brain - S3E45 - You'll Never Eat Food Pellets In This Town, Again!.avi       267.83
#  24 75odf161c5   Animaniacs - S1E15 - Pinky And The Brain - Battle for the Planet.avi                       74.19
#  25 f3k6by5hxo   Pinky And The Brain - S3E21 E22 - Pinky Suavo, T.H.E.Y.avi                                 252.28
#  26 41fuwbbe7p   Pinky And The Brain - S1E9 - Brainania.avi                                                 265.98
#  27 299n7x1oi0   Pinky And The Brain - S3E12 - Brain Storm.avi                                              264.10
#  28 7jdhxdzbsl   Pinky And The Brain - S1E3 E4 E5 - Tokyo Grows, That Smarts, Brainstem.avi                 276.59
#  29 swtu9k8wio   Pinky And The Brain - S2E4 - Plan Brain From Outer Space.avi                               257.80
#  30 yol9rt1tug   Pinky And The Brain - S2E1 - It's Only a Paper World.avi                                   254.21
#  31 5fs0k9ralt   Pinky And The Brain - S1E6 E7 E8 - Pinky And The Fog, Where No Mouse Has Gone Before, Cheese Roll Call.avi 268.93
#  32 tc4nm7j9p0   Pinky And The Brain - S3E18 - Brain Acres.avi                                              265.46
#  33 kx5kg0xm4r   Pinky And The Brain - S3E47 E48 - Whatever Happened To Baby Brain, Just Say Narf.avi       265.30
#  34 10hba474xp   Pinky And The Brain - S1E13 - Snowball.avi                                                 269.68
#  35 f1n7m7sq37   Pinky And The Brain - S3E26 - Brainy Jack.avi                                              265.52
#  36 xu6wrtry82   Pinky And The Brain - S3E43 E44 - Pinky's Turn, Your Friend Global Domination.avi          264.73
#  37 aelibu3ot4   Pinky And The Brain - S2E9 - Welcome To The Jungle.avi                                     279.22
#  38 akl5ckjezj   Pinky And The Brain - S4E9 - Star Warners.avi                                              214.67
#  39 ak4j5quaha   Pinky And The Brain - S3E39 - Inherit The Wheeze.avi                                       262.91
#  40 slz77fn7ur   Pinky And The Brain - S3E11 - This Old Mouse.avi                                           256.52
#  41 5h6ruhnqqp   Pinky And The Brain - S3E24 - Brain's Way.avi                                              266.49
#  42 cm4hnhqtgn   Pinky And The Brain - S2E5 E6 - Robin Brain, The Mummy.avi                                 270.20
#  43 c4xhlmjcsu   Pinky And The Brain - S2E10 E11 - A Little Off the Top, Megalomaniacs Anonymous.avi        246.35
#  44 f6oam7i6kh   Pinky And The Brain - S2E16 - Hoop Schemes.avi                                             264.64
#  45 16rdodtbgx   Pinky And The Brain - S3E23 - The Real Life.avi                                            277.71
#  46 e4lawhx85t   Pinky And The Brain - S2E15 - Brinky.avi                                                   264.93
#  47 qvyvuolas0   Pinky And The Brain - S4E4 E5 - To Russia With Lab Mice, Hickory Dickory Bonk.avi          264.38
#  48 vml5hbh39h   Pinky And The Brain - S4E3 - Brainwashed(3) Wash Harder.avi                                265.73
#  49 6vcgwcuuf9   Pinky And The Brain - S1E14 - Around the World in 80 Narfs.avi                             265.93
#  50 p3aovigjkn   Pinky And The Brain - S1E2 - Of Mouse and Man.avi                                          264.39
#  51 njpdps1e6b   Pinky And The Brain - S3E6 E7 - Brain's Bogie, Say What, Earth(question mark).avi          251.09
#  52 mol422qxuw   Pinky And The Brain - S1E11 - Napoleon Brainaparte.avi                                     266.50
#  53 xvzc91407v   Pinky And The Brain - S2E7 - The Pink Candidate.avi                                        267.75
#  54 i8wtfd02un   Pinky And The Brain - S1E16 E17 - Ambulatory Abe, Mouse of la Mancha.avi                   254.08
#  55 55kj3jujrh   Animaniacs - S1E18 - Pinky And The Brain - Pavlov's Mice + Animaniac's intro.avi           84.18
#  56 dntbgsl97q   Pinky And The Brain - S3E30 E31 - Operation Sea Lion, You Said A Mouseful.avi              269.13
#  57 aa9cqap33a   Pinky And The Brain - S3E16 E17 - Mice Don't Dance, Brain Drained.avi                      267.41
#  58 hqt54qi9wu   Pinky And The Brain - S2E8 - Brain's Song.avi                                              260.01
#  59 znt9mci3z4   Pinky And The Brain - S2E12 E13 - Two Mice and a Baby, The Maze.avi                        268.87
#  60 az18vve4gs   Pinky And The Brain - S3E40 E41 - Brain's Night Off - Beach Blanket Brain.avi              266.64
#  61 az05stfsqy   Pinky And The Brain - S1E18 E19 - The Third Mouse, The Visit.avi                           280.18
#  62 9ej8tav3jk   Pinky And The Brain - S3E8 - My Feldmans, My Friends.avi                                   240.32
#  63 1wk1mff72e   Pinky And The Brain - S3E15 - The Pinky Protocol.avi                                       251.41
#  64 06oih1wxtj   Pinky And The Brain - S3E32 E33 - The Tailor And The Mice, Bah, Wilderness.avi             264.41
#  65 jw66emv9bc   Pinky And The Brain - S4E7 E8 - A Legendary Tail, Project B.R.A.I.N..avi                   265.61
#  66 8s33di8lnv   Pinky And The Brain - S3E13 E14 - A Meticulous Analysis Of History, Funny, You Don't Look Rhennish.avi 264.95
#  67 z6knmonyd6   Pinky And The Brain - S2E14 - Brain Of The Future.avi                                      259.33
#  68 dj0p2tip93   Pinky And The Brain - S2E2 E3 - Collect 'Em All, Pinkasso.avi                              255.33

# %%
type(a_bitport_dir_ob)
# Out:
# __main__.BitportDir

# %%
a_bitport_dir_ob.date
# Out:
# ''

# %%
BiBo.obj_list.index
# Out:
# <function list.index>

# %%
BiBo.dirs
# Out:
# [<__main__.BitportDir at 0x10574d2e8>,
#  <__main__.BitportDir at 0x10574d518>,
#  <__main__.BitportDir at 0x10574d550>,
#  <__main__.BitportDir at 0x10574d588>,
#  <__main__.BitportDir at 0x10574d5c0>,
#  <__main__.BitportDir at 0x10574d5f8>]
