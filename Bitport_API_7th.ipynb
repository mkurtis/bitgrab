# %%
'''
Bitport MP4 Grabber.

In Late August someone tried to hack Bitport, and so they increased security, making regular scraping
very difficult.  Insead, here, we use their API to provide a way to easily download bunches of MP4 files.
'''

import requests
import json
from pprint import pprint
import os
import re
debug = False



class BitportBlob(object):
    '''
    The main object.  Has all your bitport items which are also objects (BitportDirs and BitportFiles)
    '''
    instance_names = []  

    def __init__(self, name):
        self.name = name
        BitportBlob.instance_names.append(self.name)
        self.obj_list = []
        self.auth_tok = ''
        self.me_info = {}
        self.all_bpf_objects = {}
        self.dirs = []
        self.files_to_download = []
        
        
class BitportDir(object):
    '''
    One bitport directory.
    '''
    instance_names = []

    def __init__(self, name):
        self.name = name
        BitportDir.instance_names.append(self.name)
        self.dictoid = {}
        #self.date = ''
        #self.name = ''
        #self.count = 0
        self.flist = []
        self.fact = ''

        

def get_secrets_from_file(bitport_dot_file = ''):
    '''
    Keep secret stuff in a .bitport file rather than embedded in the code.
    This utility reads the file and returns a dict.  (or else creates the file.)
    One arg: bitport_dot_file is optional, and defaults to ~/.bitport
    '''
    
    
    # File should contain what dummy_file_content contains (but with real info instead of <..GOES_HERE> stuff)
    dummy_file_content = {
      "client_id":"<CLIENT_ID_GOES_HERE>",
      "client_secret": "<CLIENT_SECRET_GOES_HERE>",
      "code": "<CODE_GOES_HERE>"
    } 
    
    if bitport_dot_file == '':
        home_dir_path = os.path.expanduser('~')
        bitport_dot_file = home_dir_path + '/.bitport'
    
    if os.path.isfile(bitport_dot_file):
        if debug: print ('File {} already exists, reading...'.format(bitport_dot_file))
        

        try:
            with open(bitport_dot_file,  'r') as fh:                                                             
                mystuff = json.load(fh)  

            if debug: print("FOUND FILE CONTENTS: [[[{}]]]".format(mystuff))
        except:
            print('UHHHhhhh, problem with file ', bitport_dot_file, ' game over.')
            
            
        if re.search (r'_GOES_HERE>', mystuff['code']):
            print('Did you forget to edit the file {} ?\n Exiting!'.format(bitport_dot_file))
            exit('Game over')

        return mystuff

            
    else:
        print ('File {} not found.   Creating....'.format(bitport_dot_file))
        print ('You must go edit the file: {}'.format(bitport_dot_file))
        exit('Game over!')

        with open(bitport_dot_file, 'w') as fh:                                                             
            json.dump(dummy_file_content, fh)    
            

        return False
            
        
        
def find_object(field, object_list):
    '''
    Check 'object_list' to see if an object with a 'name' attribute equal to 'field' exists, return it if so.
    '''
    
    for item in object_list:
        if item.name == field:
            return item
    return None



def get_auth_tok(url='https://api.bitport.io/v2/oauth2/access-token'):
    '''
    This method does a POST to http://bitport.io/get-access to obtain the 'code' (a.k.a. USER_CODE), 
    per the Bitport doc, "thanks to which you can get access_token" [sic]. 

    Beware that the 'code' seems to change occasionally, but the old one still works. So, it may be that
    a human needs to be logged in to a browser and hit the ./get-access site to get a new one occasionally.

    The requests.post below should yield a blob containing 3 items;
    token_type":"Bearer","expires_in":157766399,"access_token":"eyJ0eXAiOiJKV1QiLCJhbGciO...."
    
    We ony care about, (and therefore only return), the 'access_token' item.  Once we have the access_token
    we can make API calls to do useful stuff on the Bitport site.
    
    For more information see the (very terse) Bitport documentation available here: https://bitport.io/api

    '''
    
   
    
    dict1 = get_secrets_from_file()

    payload = {'type': 'application/x-www-form-urlencoded', 
               'client_id':'?', 
               'client_secret': '?', 
               'grant_type': 'code', 
               'code': '?'} 
    
    # We read those things from a file for a reason, they are needed in the payload;
    # We keep them out of the distro / git repo.   They are secrets!
    payload['client_id']     = dict1['client_id']
    payload['client_secret'] = dict1['client_secret']
    payload['code']          = dict1['code']

    if debug: print('Payload is \n'), pprint(payload)
    
    
    r = requests.post(url, data=payload)
    if ( r.status_code != 200 ):
        print("\n\nPOST was a FAILURE!!   status_code = : ", r.status_code, "\n\n")
        return False
    else:
        resp = json.loads(r.text)
        return resp['access_token']


    
def jsonify_req_obj(robj):
    import json
    rt = json.loads(robj.text)

    return rt


def bitport_api_cloud(tok):
    '''
    This returns a top level look at your Bitport cloud content.
    '''
    api_url = 'https://api.bitport.io/v2/cloud'

    header = {'Authorization': tok } 

    rr = requests.get(api_url, headers = header)
    return rr


def get_a_files_download_url(tok, fcode):
    
    ''' 
    Hit url/website to get more file details (only one we care about is download url)
    Take the 'fileCode', which looks like this: wzskcf8bls
    use that in the https://api.bitport.io/v2/files/<....>/stream.m3u8 url, and 
    get a result that looks like this;
    
    ['#EXTM3U',
     '#EXT-X-VERSION:4',
     '#EXT-X-TARGETDURATION:3556',
     '#EXT-X-MEDIA-SEQUENCE:0',
     '#EXTINF:3556',
     'https://s04.bitport.io/download/uGDWG96J1QRpEFQnntfzsp49vbkK1oba/1',
     '#EXT-X-ENDLIST']
    
    Then parse out and return just the https (url) piece.
    
    '''
    
    api_url = 'https://api.bitport.io/v2/files/' + fcode + '/stream.m3u8'

    header = {'Authorization': tok } 

    rr = requests.get(api_url, headers = header)
    
    pat = r'(http.+1)\n'
    import re
    found = re.search(pat, rr.text)
    if debug: print('0=[{}]'.format(found.group(0)))
    if debug: print('1=[{}]'.format(found.group(1)))

    if debug: print('finalanswer[[[{}]]]'.format(found.group(1)[3]))

    return found.group(1)

        

    
def get_me_info_from_api(tok):
    '''
    This returns a top level look at your Bitport cloud content.
    '''
    api_url = 'https://api.bitport.io/v2/me'

    header = {'Authorization': tok } 

    rr = requests.get(api_url, headers = header)
    jj = jsonify_req_obj(rr)
    
    return jj['data']




def bitport_api_get_folder(tok, dir_code):
    api_url = 'https://api.bitport.io/v2/cloud/' + dir_code
    header = {'Authorization': tok }
    rr = requests.get(api_url, headers = header)
    return rr






def munge_dir_req_obj(bitport_api_get_folder_results):

    dstruct = jsonify_req_obj(bitport_api_get_folder_results)
    min_size = 10000000  # sometimes a 'sample' file is included.  We want to skip it.  Size is in bytes?
    hits = 0
    file_url_prefix = 'https://bitport.io/my-files/file/'
    good_video_file_urls = []
    #pprint(dstruct)


    #print("AAA", dstruct['data'][0])
    print("date=", dstruct['data'][0]['created_at']['date'])
    print("name=", dstruct['data'][0]['name'])
    print("count=", dstruct['data'][0]['files_count'])
    for ff in dstruct['data'][0]['files']:
        temp_dict = {}
        if re.search(r'^sample[.]', ff['name']) and ff['size'] < min_size:
            if debug: print(ff['name'], 'is a small file that starts with "sample.", skipping...')
        elif ff['screenshots'] == []:
            if debug: print(ff['name'], 'has no screenshots, skipping...')
        else:
            hits += 1
            ans = ff
            if debug: print('\tWINNER: ', ff['code'], ff['name'], ff['size'])
            temp_dict['code'] = ff['code']
            temp_dict['parent_folder_code'] = ff['parent_folder_code']
            temp_dict['size'] = ff['size']
            temp_dict['name'] = ff['name']
            temp_dict['date'] = ff['created_at']['date']
            temp_dict['url'] = file_url_prefix + ff['code']

            
            good_video_file_urls.append(temp_dict)
            
    print('munge_dir_req_obj() returning with {} items: {}'.format(hits, good_video_file_urls))       
    return good_video_file_urls




def paint_h():
    
    
    print('{:>3} {:<12} {:<90} {:>5}'.format(
            'Row',
            'Code', 
            'Name',
            'Size(MB)')
         )
    print('{:>3} {:<12} {:<90} {:>5}'.format(
            '=' * 3,
            '=' * 12, 
            '=' * 82,
            '=' * 5)
         )
    
    
    
def paint_r(row, dictx):
    
    mb = 1024 * 1024
    
    debug = False
    if debug: print('I am "paint_r", called with [{}] and [{}]'.format(row, dictx))
    
    print('{:>3} {:<12} {:<90} {:<5.2f}'.format(
            row,
            dictx['code'], 
            dictx['name'],
            dictx['size'] / mb)
         )
    
    
def figure_out_dirs( the_cloud_api_requests_object):
    dict_list = []
    xx = jsonify_req_obj(the_cloud_api_requests_object)
    files_dict = xx['data'][0]['folders']
    for file_item in files_dict:
        if file_item['files_count'] > 0:

            temp_obj = BitportDir(file_item['code'])

            temp_obj.dictoid = {'name':         file_item['name'],
                                 'size':        file_item['size'], 
                                 'files_count': file_item['files_count'], 
                                 'code':    file_item['code']  
                                }

            dict_list.append(temp_obj)
    return dict_list




def print_top_level_choice(bpobj):
    
    paint_h()

    for zz in range(len(bpobj.dirs)):
        #print('line {}'.format(zz))
        #print(bpobj.dirs[zz].dictoid)
        paint_r(zz, bpobj.dirs[zz].dictoid)


        
        
def paint_dirs_files(directory_objects_file_list):

    paint_h()
    
    debug = False
    if debug: pprint(directory_objects_file_list)
    
    for item_num in range(len(directory_objects_file_list)):
        paint_r(item_num, directory_objects_file_list[item_num])

    
    
    

    
    

def get_all_dem_file_download_urls(tok, dobj):
    all_urls = []
    all_sm_urls = []
    
    
    dir_url = 'https://bitport.io/my-files/' + dobj.name
    print('Getting file download urls for dir: {}'.format(dir_url))
        
    for ff in dobj.flist:
        print("Grabbing download url for file code {}".format(ff['code']))

        download_url = get_a_files_download_url(BiBo.auth_tok, ff['code'])
        download_url_sm = re.sub(r'/1$', '/2', download_url)   # 'cuz small is known to be just the ../2
        
        ff['download_url'] = download_url
        ff['download_url_sm'] = download_url_sm
        
        all_urls.append(download_url)
        all_sm_urls.append(download_url_sm)
        
    return all_urls, all_sm_urls





def download_file(download_url, file_path):
    '''
    Take a url and filename, use the requests lib in stream mode to download the file.
    '''
    import re
    
    file_path = re.sub(r'[?]$', '', file_path)  # removing trailing '?'                 
    
    print('Downloading file {}'.format(file_path), end='')
    rr = requests.get(download_url, stream=True) 

    with open(file_path, 'wb') as fd:
        for chunk in rr.iter_content(chunk_size=2**24):  # 2^24 = 16MB
            print('.', end='')
            fd.write(chunk)
            
    print('\nDone.')

# %%
import re

def ui2(file_obj):
    max_range = len(file_obj.flist)
    loop = True
    while loop:
        user_pick_f = input('Pick one by number, or \"A\" for All:')
        
        # If user picks a 1, 2, 3, ... we convert it to int so we can use it as a list index;
        mat = re.match(r'[0123456789]', user_pick_f)
        if mat:
            user_pick_f = int(user_pick_f)
            
        print('Youpicked[{}], of type: {}'.format(user_pick_f, type(user_pick_f)))
        
        # USER WANTS ONE FILE;
        if user_pick_f in range(0, max_range):
            print('Call ONE here with {} (type is type {})'.format(user_pick_f, type(user_pick_f)))
            paint_h()
            paint_r(user_pick_f, file_obj.flist[0])
            print( get_a_files_download_url(BiBo.auth_tok,file_obj.flist[0]['code']) )

            file_obj.flist[user_pick_f]['download_url'] = get_a_files_download_url(BiBo.auth_tok,tt.flist[user_pick_f]['code'])
            loop = False

            
        # USER WANTS ALL FILES:
        elif user_pick_f in [ 'A', 'a']:
            print('Getting all...{}', type(user_pick_f))
            (durls, durls_sm) = get_all_dem_file_download_urls(BiBo.auth_tok, file_obj)
            pick = input('Do you want to download Small, Large, or None?:')
  

            # SMALL
            if pick == 'S' or pick == 's':
                for item in durls_sm:
                    print(item)
                y_or_n = input('Are you sure you want all of these?:')
                if y_or_n == 'Y' or y_or_n == 'y':
                    for ii in file_obj.flist:
                        ur = ii['download_url_sm']
                        nm = ii['name'] 
                        nm = re.sub(r'[.][aA][vV][iI]$', '_SM.MP4', nm )  # if it ends with .AVI, change to _SM.MP4
                        download_file(ur, nm)
                    print('All done!')
                else:
                    print('Good.  You\'re saving bandwidth and disk space!')

                    
            # LARGE
            elif pick == 'L' or pick == 'l':
                for item in durls:
                    print(item)  
                y_or_n = input('Are you sure you want all of these?:')
                if y_or_n == 'Y' or y_or_n == 'y':
                    for ii in file_obj.flist:
                        ur = ii['download_url']
                        nm = ii['name'] 
                        nm = re.sub(r'[.][aA][vV][iI]$', '.MP4', nm )  # if it ends with .AVI, change to .MP4
                        nm = '/Volumes/JUNK' + nm
                        download_file(ur, nm)
                    print('All done!')
                else:
                    print('Good.  You\'re saving bandwidth and disk space!')
                
            # USER WANTS NOTHING!
            else:
                print('Caution is a virtue')

            loop = False
            
        else:
            print('Invalid Response, Pick a number between 0 and {}, or \"A\" for all'.format(max_range))

# %%
BiBo = BitportBlob('mmm')
BiBo.auth_tok = get_auth_tok()
print(BiBo.auth_tok)
# Out:
# eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsImp0aSI6ImQzYWM2ZGVhNDI3ZjExMDU5MTE4MmI4MGVjOTQwYzI5YWNjMTdiMzFkNDc1N2UwODI4ZWYxYzMyOGYxMWNmZjQ5MTIwYjM2Nzc1OTIxNWJhIn0.eyJhdWQiOiI0Mzg4MCIsImp0aSI6ImQzYWM2ZGVhNDI3ZjExMDU5MTE4MmI4MGVjOTQwYzI5YWNjMTdiMzFkNDc1N2UwODI4ZWYxYzMyOGYxMWNmZjQ5MTIwYjM2Nzc1OTIxNWJhIiwiaWF0IjoxNTA2Mjk2NTU5LCJuYmYiOjE1MDYyOTY1NTksImV4cCI6MTY2NDA2Mjk1OSwic3ViIjoiMzM4MTQ0Iiwic2NvcGVzIjpbXX0.WJVY-9yaa0ximDnlV9wTRigcQis4HYR58iLjDTqgYX38wRgGP9zl_cjbSeYrC-IGiZAv7JY67Y0tF0NvLPh6Z1TTUA6hlosmZ_5QjJzU5TnN_bDc6tsV5xB8VtekfLsauGds_TXb1j179NH4OW0gZlYqm08dcjmFVO2B8yNLDTQ

# %%
user_input = 99
BiBo.me_info = get_me_info_from_api(BiBo.auth_tok)
BiBo.dirs = figure_out_dirs(bitport_api_cloud(BiBo.auth_tok))
print_top_level_choice(BiBo)
# print('#' * 100)


while user_input not in range(0,len(BiBo.dirs)):
    user_input = int(input('Pick a number: '))

dir_code = BiBo.dirs[user_input].dictoid['code']
print("DIRCODE IS {}".format(dir_code))
print('Files from choice {}, the {} dir;\n'.format(user_input, dir_code ))
paint_h()
paint_r(user_input, BiBo.dirs[user_input].dictoid)

# Call API on folder -- get a requests object;
one_dirs_requests_obj = bitport_api_get_folder(BiBo.auth_tok, dir_code)

# Populate that dir object's .flist
#a_bitport_dir_ob.flist = munge_dir_req_obj(one_dirs_requests_obj)
#ttt = find_object('40p3set1sc', BiBo.dirs)

BiBo.dirs[user_input].flist = munge_dir_req_obj(one_dirs_requests_obj) 




paint_dirs_files(BiBo.dirs[user_input].flist)


ui2(BiBo.dirs[user_input])
# Out:
# Row Code         Name                                                                                       Size(MB)
# === ============ ==================================================================================         =====
#   0 8yzfuvl00s   Pinky and the Brain                                                                        17405.20
#   1 7yd1vjxluk   Rick.and.Morty.S03E08.720p.HDTV.x264-BATV[rarbg]                                           486.32
#   2 sjyi4ww4ry   The.Red.Turtle.2016.BRRip.XviD.AC3-EVO                                                     1220.78
#   3 7yx1y5wu7y   Inception [2010] 1080p BluRay AAC x264-ETRG                                                3992.07
# Pick a number: 0
# DIRCODE IS 8yzfuvl00s
# Files from choice 0, the 8yzfuvl00s dir;
#
# Row Code         Name                                                                                       Size(MB)
# === ============ ==================================================================================         =====
#   0 8yzfuvl00s   Pinky and the Brain                                                                        17405.20
# date= 2017-07-07 16:54:05.000000
# name= Pinky and the Brain
# count= 70
# munge_dir_req_obj() returning with 69 items: [{'parent_folder_code': '8yzfuvl00s', 'name': 'Pinky And The Brain - S3E46 - Dangerous Brains.avi', 'code': 'cnrdyyzwy3', 'url': 'https://bitport.io/my-files/file/cnrdyyzwy3', 'date': '2017-07-07 16:54:05.000000', 'size': 279282288}, {'parent_folder_code': '8yzfuvl00s', 'name': 'Animaniacs - S1E98 - Pinky And The Brain - Opportunity Knox.avi', 'code': 'e94evbqrkz', 'url': 'https://bitport.io/my-files/file/e94evbqrkz', 'date': '2017-07-07 16:54:05.000000', 'size': 117655758}, {'parent_folder_code': '8yzfuvl00s', 'name': 'Pinky And The Brain -
#  55 55kj3jujrh   Animaniacs - S1E18 - Pinky And The Brain - Pavlov's Mice + Animaniac's intro.avi           84.18
#  56 dntbgsl97q   Pinky And The Brain - S3E30 E31 - Operation Sea Lion, You Said A Mouseful.avi              269.13
#  57 aa9cqap33a   Pinky And The Brain - S3E16 E17 - Mice Don't Dance, Brain Drained.avi                      267.41
#  58 hqt54qi9wu   Pinky And The Brain - S2E8 - Brain's Song.avi                                              260.01
#  59 znt9mci3z4   Pinky And The Brain - S2E12 E13 - Two Mice and a Baby, The Maze.avi                        268.87
#  60 az18vve4gs   Pinky And The Brain - S3E40 E41 - Brain's Night Off - Beach Blanket Brain.avi              266.64
#  61 az05stfsqy   Pinky And The Brain - S1E18 E19 - The Third Mouse, The Visit.avi                           280.18
#  62 9ej8tav3jk   Pinky And The Brain - S3E8 - My Feldmans, My Friends.avi                                   240.32
#  63 1wk1mff72e   Pinky And The Brain - S3E15 - The Pinky Protocol.avi                                       251.41
#  64 06oih1wxtj   Pinky And The Brain - S3E32 E33 - The Tailor And The Mice, Bah, Wilderness.avi             264.41
#  65 jw66emv9bc   Pinky And The Brain - S4E7 E8 - A Legendary Tail, Project B.R.A.I.N..avi                   265.61
#  66 8s33di8lnv   Pinky And The Brain - S3E13 E14 - A Meticulous Analysis Of History, Funny, You Don't Look Rhennish.avi 264.95
#  67 z6knmonyd6   Pinky And The Brain - S2E14 - Brain Of The Future.avi                                      259.33
#  68 dj0p2tip93   Pinky And The Brain - S2E2 E3 - Collect 'Em All, Pinkasso.avi                              255.33
# Pick one by number, or "A" for All:a
# Youpicked[a], of type: <class 'str'>
# Getting all...{} <class 'str'>
# Getting file download urls for dir: https://bitport.io/my-files/8yzfuvl00s
# Grabbing download url for file code cnrdyyzwy3
# Grabbing download url for file code e94evbqrkz
# Grabbing download url for file code c4cfacrp5h
# Grabbing download url for file code 4wkov28ice
# Grabbing download url for file code ptj13p1iqm
# Grabbing download url for file code pgtrzlr1y5
# Grabbing download url for file code lsotejeosx
# Grabbing download url for file code n17umcud4f
# Grabbing download url for file code 2qzt0c6a4q
# Grabbing download url for file code yv6028n48z
# Grabbing download url for file code z94etenqr1
# Grabbing download url for file code pah6g0vh74
# Grabbing download url for file code j3hyym3n07
# Grabbing download url for file code 26gxt7zbru
# Grabbing download url for file code nl7jzr04us
# Grabbing download url for file code w3dfhbiryo
# Grabbing download url for file code 5e5r1xb256
# Grabbing download url for file code 995x0fuq2m
# Grabbing download url for file code nx8w674ihk
# Grabbing download url for file code z3qcie9zk2
# Grabbing download url for file code youaldqqbi
# Grabbing download url for file code uo6wj2szbx
# Grabbing download url for file code 2b1nkc0vj4
# Grabbing download url for file code 9kb8lrse6u
# Grabbing download url for file code 75odf161c5
# Grabbing download url for file code f3k6by5hxo
# Grabbing download url for file code 41fuwbbe7p
# Grabbing download url for file code 299n7x1oi0
# Grabbing download url for file code 7jdhxdzbsl
# Grabbing download url for file code swtu9k8wio
# Grabbing download url for file code yol9rt1tug
# Grabbing download url for file code 5fs0k9ralt
# Grabbing download url for file code tc4nm7j9p0
# Grabbing download url for file code kx5kg0xm4r
# Grabbing download url for file code 10hba474xp
# Grabbing download url for file code f1n7m7sq37
# Grabbing download url for file code xu6wrtry82
# Grabbing download url for file code aelibu3ot4
# Grabbing download url for file code akl5ckjezj
# Grabbing download url for file code ak4j5quaha
# Grabbing download url for file code slz77fn7ur
# Grabbing download url for file code 5h6ruhnqqp
# Grabbing download url for file code cm4hnhqtgn
# Grabbing download url for file code c4xhlmjcsu
# Grabbing download url for file code f6oam7i6kh
# Grabbing download url for file code 16rdodtbgx
# Grabbing download url for file code e4lawhx85t
# Grabbing download url for file code qvyvuolas0
# Grabbing download url for file code vml5hbh39h
# Grabbing download url for file code 6vcgwcuuf9
# Grabbing download url for file code p3aovigjkn
# Grabbing download url for file code njpdps1e6b
# Grabbing download url for file code mol422qxuw
# Grabbing download url for file code xvzc91407v
# Grabbing download url for file code i8wtfd02un
# Grabbing download url for file code 55kj3jujrh
# Grabbing download url for file code dntbgsl97q
# Grabbing download url for file code aa9cqap33a
# Grabbing download url for file code hqt54qi9wu
# Grabbing download url for file code znt9mci3z4
# Grabbing download url for file code az18vve4gs
# Grabbing download url for file code az05stfsqy
# Grabbing download url for file code 9ej8tav3jk
# Grabbing download url for file code 1wk1mff72e
# Grabbing download url for file code 06oih1wxtj
# Grabbing download url for file code jw66emv9bc
# Grabbing download url for file code 8s33di8lnv
# Grabbing download url for file code z6knmonyd6
# Grabbing download url for file code dj0p2tip93
# Do you want to download Small, Large, or None?:l
# https://s06.bitport.io/download/5OWWVno58F33vahMH8Dhkd0Xe5BFcFEM/1
# https://s05.bitport.io/download/2m219V7n2tz4hSDzETn7t5omTNzJKnyr/1
# https://s13.bitport.io/download/I8CxvOkViJbvQu1O6XmfyaII6kK2U92k/1
# https://s04.bitport.io/download/tTOaGh50mtBYcZJtJlW2v7U7m9PpCTNd/1
# https://s06.bitport.io/download/dae0jhIhsRRevKJ452bwT0n42fevJnUi/1
# https://s06.bitport.io/download/ZJ1jKPSLWJRcIUZxlIc7N4Np3tWGgReR/1
# https://s03.bitport.io/download/bUSkGddAYOmeGwp3RmCe2ZErH5oYLLVA/1
# https://s06.bitport.io/download/EdkkoTqnxhWGlUiKhOiRZCQgEohfCd1g/1
# https://s06.bitport.io/download/1cEObmev5RRa5RUWQrPTFE1TZiCXKT89/1
# https://s06.bitport.io/download/cAeeNmsQ1ehHVGdpJS9Fqrnuyq4LKdJ2/1
# https://s05.bitport.io/download/nAHDnfCDGrsSVbqHTOr6jAdzleX3Wbw7/1
# https://s05.bitport.io/download/KxlN1ErSK0OqgfIX0ZFkRnrvmmVHeRs3/1
# https://s05.bitport.io/download/JXuVCgtDchTdV53GeodAjbtAujIfY4cf/1
# https://s03.bitport.io/download/AZ7oLdiuq25JICyayVkkXrhXaWmM1zCv/1
# https://s12.bitport.io/download/02YIZ57uyyFcsTsQpq26hUP35gVkNDzE/1
# https://s05.bitport.io/download/xmqDaOesajv6N9JxPSKR8S4UJcT9VsfC/1
# https://s05.bitport.io/download/01BFZClKwaOuU8cnJla6tAkGYCyYB62S/1
# https://s06.bitport.io/download/XRFyWtTKCcR1d1eTyrk8rWC1soPhLn1b/1
# https://s06.bitport.io/download/daUK4ejKdyu8ZB8bgb6Lho7typ2f57V3/1
# https://s05.bitport.io/download/ebU8QBdrv6F7dUpZTokhaqtOBFVsgN0N/1
# https://s06.bitport.io/download/OQvvQcloZnyzNxdar3vZkNMgwe0edF8b/1
# https://s06.bitport.io/download/QbNTNCseupee4ZJVlEoe4xs1Xf4nZ9pR/1
# https://s05.bitport.io/download/RFMYkIEA75c08Cv00e8PkefqrIsuNMaZ/1
# https://s04.bitport.io/download/8bU8eN6ySGHgvbrKKAgBRbrjhO822IkR/1
# https://s06.bitport.io/download/ixa0raKP3rSirwyflnUYOwIEh8GJpYje/1
# https://s05.bitport.io/download/YebNpOddoA4xe8YiTimTuSD9krjwky6W/1
# https://s05.bitport.io/download/GCQyPTbzJVIdvQbYwbVyalP6rTW0Hlqk/1
# https://s04.bitport.io/download/HAvbi6h6knFG5GzgnwTAe2ON9JRSt7cE/1
# https://s03.bitport.io/download/WzVEGzmP9P1fbJ87XrQubXkcIZwJYvYB/1
# https://s06.bitport.io/download/QdbYx7TCmChd1jpfkUOSdUpxRkIsxrI7/1
# https://s05.bitport.io/download/ByyJicgZBGaKUiYgaDaHbzrDCGHsJKyE/1
# https://s06.bitport.io/download/ptSNpcFbLvRMcEj3vTlStVZ5FgLcrELw/1
# https://s05.bitport.io/download/zngURs77EE3zPz37t1AbQqlffAM12iFR/1
# https://s11.bitport.io/download/iiZ5QDUTYoiKuXQGyLnWyfSk8dD0YnmL/1
# https://s06.bitport.io/download/OPyXVpLscUXRhxBGWOq3I5FqJ075Z3cx/1
# https://s15.bitport.io/download/pQatnM3n183m0mVQ4a6u98GNrsMMhZZ2/1
# https://s10.bitport.io/download/vPR8XpBXFOAQQfhgqOJXUGguHOolON46/1
# https://s03.bitport.io/download/Ml7bmWE2xA4g1MoqW8b8mItYUTuoP7I9/1
# https://s06.bitport.io/download/0Qt3oplSokN2qG9h7ozJmxBktpcqh9w1/1
# https://s06.bitport.io/download/aXxpio3oe1SRE9a4S20dN4hTvvNWuePu/1
# https://s03.bitport.io/download/sLgzpp7ugcxZbilyDWGoyub0B4QLdWvy/1
# https://s05.bitport.io/download/ChMipXyHgb8pZKHD0tyM6W2GsuokALvC/1
# https://s05.bitport.io/download/rVejYFiXSxb5pmZU4yBpVBuyBfZsnzI1/1
# https://s05.bitport.io/download/RWwP7hCKGYDMBY3bSf8eZjuHIP764YJG/1
# https://s11.bitport.io/download/XZcPUuYxXMeeHdkyTh9xjSB7ODi017f5/1
# https://s05.bitport.io/download/JYmQdeR6XGInKCbVe0sh2eQQYAZeKbOf/1
# https://s04.bitport.io/download/E1KvmdUZs32BJHj5Z3KibipN6LrcKhj6/1
# https://s05.bitport.io/download/3p4ORWHxVvWUMvrq3DK6BGKwhKbwbSWK/1
# https://s03.bitport.io/download/0Sgaffbq6qV1UdxTBmEdHGM04YG3RMDc/1
# https://s06.bitport.io/download/kl1zasT8ygpeVC0nqWzf4iZ6XlZcGJyI/1
# https://s15.bitport.io/download/V1jRMVn4wEBp33acUKrJuFkVUgeZVte3/1
# https://s05.bitport.io/download/hx86uX1whkvo7qwTpJv0uj5YNAJYwL6C/1
# https://s05.bitport.io/download/VauhjG1wCtXoKt84N9zwsVKqEm3guyqL/1
# https://s05.bitport.io/download/ziNvk4LzQHd2kMgCeDOrti16wm8gG0dV/1
# https://s05.bitport.io/download/YEDHPcyvAV40CNRNqDqWWuEJc3Canf3p/1
# https://s06.bitport.io/download/LpsVT6G4rlNkgTMcgnfMWVIVCDCsUTWa/1
# https://s03.bitport.io/download/oXEb5wNBIs7XnUU6GJsyuErYFdbqgMoj/1
# https://s12.bitport.io/download/GyLl6OR7ibsQXy7hwcvNMchdH5x76rn2/1
# https://s03.bitport.io/download/6ZG9VyDN7afA4hFPFf3wow90TlzKFtQF/1
# https://s04.bitport.io/download/i8ju7Qu5Xif22sl1Ag9hTL6JcbgOBSBz/1
# https://s06.bitport.io/download/VIAM7MpFaQhWgEYPWVM1pkdOmzibq8LR/1
# https://s06.bitport.io/download/GHJ0ZYoiny5cVvrSufdojzZwDvBSTz8W/1
# https://s04.bitport.io/download/I3O9ri3upJJ1gYJCbBB2w0bYmSQu8GSt/1
# https://s06.bitport.io/download/7hYNyjxlPag5Aq7FUldUqgR2qrorJov8/1
# https://s03.bitport.io/download/5NKdMVLlfRjUF2aJXzFZ9qfUsAmmksfn/1
# https://s13.bitport.io/download/x68taSbwMDKaU32ODZQlQGJHQA3pldPH/1
# https://s10.bitport.io/download/ykGmWZ0Hgy89uOnaMSAjnzzotowfcb4c/1
# https://s03.bitport.io/download/djJZkhgwBRbVMb7cwivDxrU21agiEatn/1
# https://s06.bitport.io/download/PGRf2uxBlBtkgdiSkoQuGL4Nc2XGCim3/1
# Are you sure you want all of these?:y
# Downloading file /Volumes/JUNKPinky And The Brain - S3E46 - Dangerous Brains.MP4........
# Done.
# Downloading file /Volumes/JUNKAnimaniacs - S1E98 - Pinky And The Brain - Opportunity Knox.MP4...
# Done.
# Downloading file /Volumes/JUNKPinky And The Brain - S3E5 - Brain Noir.MP4........
# Done.
# Downloading file /Volumes/JUNKAnimaniacs - S1E39 - Pinky And The Brain - Where Rodents Dare.MP4.

# %%
for xx in BiBo.dirs:
    print('%' * 90)
    pprint(xx.dictoid)
    print('\n',xx.name, end='')
    pprint(xx.flist)

# %%
ttt.dictoid

# %%
fname = tt.flist[0]['name']
sname = tt.flist[0]['name']

# %%
fname = re.sub(r'[.][aA][vV][iI]$', '.MP4', fname )
sname = re.sub(r'[.][aA][vV][iI]$', '_SM.MP4', sname )

# %%
print(fname)
print(sname)
# Out:
# Pinky And The Brain - S3E46 - Dangerous Brains.MP4
# Pinky And The Brain - S3E46 - Dangerous Brains_SM.MP4
